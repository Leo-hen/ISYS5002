# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo-hen/ISYS5002/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Collect basic user inputs
user_name = input("What is your name? ")
fav_colour = input("What is your favourite colour? ")
fav_food = input("What is your favourite food? ")

# Display the captured inputs
print("Name:", user_name)
print("Favourite Colour:", fav_colour)
print("Favourite Food:", fav_food)
# Out:
# What is your name? leo
# What is your favourite colour? blue
# What is your favourite food? steak
# Name: leo
# Favourite Colour: blue
# Favourite Food: steak

# %%
# Output a summary message combining the inputs
print("Hello, " + user_name + "! Your favourite colour is " + fav_colour +
      " and you love " + fav_food + ".")
# Out:
# Hello, leo! Your favourite colour is blue and you love steak.

# %%
spirit_animal = input("What's your spirit animal? ")
print("Interesting choice! I wonder why a", spirit_animal, "resonates with you.")
# Out:
# What's your spirit animal? dog
# Interesting choice! I wonder why a dog resonates with you.

# %%
print("Your name in all caps is", user_name.upper() + "!")
# Out:
# Your name in all caps is LEO!

# %%
# Challenge 1: Multi-line Greeting
print("Hello, " + user_name + "! \nYour favourite colour is " + fav_colour +
      " and you love " + fav_food + ".")
# Out:
# Hello, leo!
# Your favourite colour is blue and you love steak.

# %%
#Challenge 2: Age Calculator
# Collect basic user birth year
import datetime
birth_year = int(input("What is your birth year? "))
current_year = datetime.datetime.now().year
age = current_year - birth_year

# Display the user age
print("you age is age", age)
# Out:
# What is your birth year? 2001
# you age is age 25

# %%
# Sample survey programme

# Ask the user for their preferences
name = input("What's your name? ")
favourite_colour = input("What's your favourite colour? ")
favourite_food = input("What's your favourite food? ")
favourite_movie = input("What's your favourite movie? ")

# Construct and display a summary message
print("\nHello, " + name + "!")
print("Your favourite colour is " + favourite_colour + ", you love " + favourite_food +
      ", and your favourite movie is " + favourite_movie + ".")
# Out:
# What's your name? leo
# What's your favourite colour? blue
# What's your favourite food? steak
# What's your favourite movie? coco
#
# Hello, leo!
# Your favourite colour is blue, you love steak, and your favourite movie is coco.

# %%
user_provided_name = input("What's your name? ")
print(f"Hello, {user_provided_name}!")
# Out:
# What's your name? leo
# Hello, leo!

# %%
# TODO: Add another preference.
# For example:
# favourite_hobby = input("What's your favourite hobby? ")

# TODO: Update the summary message to include your new preference.
# For example:
# print("Hello, " + name + "!")
# print("Your favourite colour is " + favourite_colour +
#       ", you love " + favourite_food +
#       ", your favourite movie is " + favourite_movie +
#       ", and you enjoy " + favourite_hobby + ".")
# Ask the user for their preferences
name = input("What's your name? ")
favourite_colour = input("What's your favourite colour? ")
favourite_food = input("What's your favourite food? ")
favourite_movie = input("What's your favourite movie? ")
favourite_hobby = input("What's your favourite hobby? ")

# Construct and display a summary message
print("\nHello, " + name + "!")
print("Your favourite colour is " + favourite_colour + ", you love " + favourite_food +
      ", and your favourite movie is " + favourite_movie + ", and you enjoy " + favourite_hobby + ".")
# Out:
# What's your name? leo
# What's your favourite colour? blue
# What's your favourite food? steak
# What's your favourite movie? coco
# What's your favourite hobby? running
#
# Hello, leo!
# Your favourite colour is blue, you love steak, and your favourite movie is coco, and you enjoy running.

# %%
#Challenge 1: Starred Preferences
# Sample survey programme

# Ask the user for their preferences
name = input("What's your name? ")
favourite_colour = input("What's your favourite colour? ")
favourite_food = input("What's your favourite food? ")
favourite_movie = input("What's your favourite movie? ")

# Construct and display a summary message
print("* Name: " + name)
print("* Favourite Colour: " + favourite_colour + "\n* Favourite Food: " + favourite_food +
      "\n* Favourite Movie: " + favourite_movie)
# Out:
# What's your name? leo
# What's your favourite colour? blue
# What's your favourite food? steak
# What's your favourite movie? coco
# * Name: LEO
# * Favourite Colour: BLUE
# * Favourite Food: STEAK
# * Favourite Movie: COCO

# %%
#Challenge 2: F-String Formatting Challenge
# Sample survey programme

# Ask the user for their preferences
name = input("What's your name? ")
favourite_colour = input("What's your favourite colour? ")
favourite_food = input("What's your favourite food? ")
favourite_movie = input("What's your favourite movie? ")

# Construct and display a summary message
print(f"\nHello, {name}!")
print(f"Your favourite colour is {favourite_colour},", f"you love {favourite_food},", f"and your favourite movie is {favourite_movie}.")
# Out:
# What's your name? 55
# What's your favourite colour? 55
# What's your favourite food? 55
# What's your favourite movie? 55
#
# Hello, 55!
# Your favourite colour is 55, you love 55, and your favourite movie is 55.

# %%
# Displaying the weather menu options
print("Weather Menu:")
print("1. Check Temperature")
print("2. Check Humidity")
print("3. Check Wind Speed")
print("4. Exit")
# Out:
# Weather Menu:
# 1. Check Temperature
# 2. Check Humidity
# 3. Check Wind Speed
# 4. Exit

# %%
# Prompting the user to enter their choice
choice = input("Enter your choice (1-4): ")
print("You selected option:", choice)
# Out:
# Enter your choice (1-4): 4
# You selected option: 4

# %%
# Example of a simple decision structure based on the user's choice
# Prompting the user to enter their choice
choice = input("Enter your choice (1-4): ")
if choice == "1":
    print("You chose to check the temperature.")
elif choice == "2":
    print("You chose to check the humidity.")
elif choice == "3":
    print("You chose to check the wind speed.")
elif choice == "4":
    print("Exiting the program.")
else:
    print("Invalid choice. Please select a valid option.")
# Out:
# Enter your choice (1-4): 1
# You chose to check the temperature.
