# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo-hen/ISYS5002/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 {"name": "Widget A", "price": 9.99, "qty_sold": 120}
# Out:
# {'name': 'Widget A', 'price': 9.99, 'qty_sold': 120}

# %%
sales_data = {
    "P001": {"name": "Widget A", "price": 9.99, "qty_sold": 120},
    "P002": {"name": "Widget B", "price": 14.50, "qty_sold": 85},
    "P003": {"name": "Widget C", "price": 7.25, "qty_sold": 200},
    "P004": {"name": "Widget D", "price": 12.75, "qty_sold": 75}
}

# %%
# Challenge 1:calculate the total revenue
total_revenue = 0
for product_id, product_info in sales_data.items():
    product_revenue = product_info['price'] * product_info['qty_sold']
    total_revenue += product_revenue

print(f"Total Revenue: ${total_revenue:.2f}")
# Out:
# Total Revenue: $4837.55

# %%
#Challenge 2 : identify the best-selling product
best_selling_product_id = None
max_qty_sold = -1

for product_id, product_info in sales_data.items():
    if product_info['qty_sold'] > max_qty_sold:
        max_qty_sold = product_info['qty_sold']
        best_selling_product_id = product_id

if best_selling_product_id:
    best_selling_product_name = sales_data[best_selling_product_id]['name']
    print(f"Best-Selling Product: {best_selling_product_name} (ID: {best_selling_product_id}) with {max_qty_sold} units sold.")
else:
    print("No sales data available to determine the best-selling product.")
# Out:
# Best-Selling Product: Widget C (ID: P003) with 200 units sold.
