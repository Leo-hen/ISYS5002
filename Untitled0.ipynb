# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo-hen/ISYS5002/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("Hello World!")
print("I am learning Python.")
# Out:
# Hello World!
# I am learning Python.

# %%
print("Python is versatile!")
print("I am learning Python!")
# Out:
# Python is versatile!
# I am learning Python!

# %%
print("Hello")
print("Python!")
# Out:
# Hello
# Python!

# %%
print("All caps")
# Out:
# All caps

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Python")
# Out:
# Python

# %%
print("I have no end")
# Out:
# I have no end

# %%
print("Good morning!")
print("Python is amazing!")
print("Let's learn Python together!")
print("Coding is exciting")
print("I have no idea what's going on!")
# Out:
# Good morning!
# Python is amazing!
# Let's learn Python together!
# Coding is exciting
# I have no idea what's going on!

# %%
print("Apple")

print("or Orange?")
# Out:
# Apple
# or Orange?

# %%
print("How")

print("are")
print("you?")
# Out:
# How
# are
# you?

# %%
print("How")
print()
print("are")
print("you?")
# Out:
# How
#
# are
# you?

# %%
print("Blank spaces matter")
print("for clarity")
print()
print("and style!")
# Out:
# Blank spaces matter
# for clarity
#
# and style!

# %%
print("This is the first line.\nThis is the second line.")
# Out:
# This is the first line.
# This is the second line.

# %%
print('''My contact:
Email: your_name@gmail.com
Phone: +xx-1234-5678''')
# Out:
# My contact:
# Email: your_name@gmail.com
# Phone: +xx-1234-5678

# %%
print("To-Do List:\n1. Complete Python exercise\n2. Review coding concepts\n3. Have a cuppa tea")
# Out:
# To-Do List:
# 1. Complete Python exercise
# 2. Review coding concepts
# 3. Have a cuppa tea

# %%
print('''To-Do List:
1. Complete Python exercise
2. Review coding concepts
3. Have a cuppa tea''')
# Out:
# To-Do List:
# 1. Complete Python exercise
# 2. Review coding concepts
# 3. Have a cuppa tea

# %%
print('''Personal Profile:
Name: Alice Smith
Favourite Language: Python
Hobby: Coding and bushwalking''')
# Out:
# Personal Profile:
# Name: Alice Smith
# Favourite Language: Python
# Hobby: Coding and bushwalking

# %%
print("Hello, World!")

print()#print() function will leave an empty line

print("This is the first line. \nThis is the second line.")#\n is used to signal Python to start a new line

print('''Three quotes can be used also
to print multiple lines using a single print function''')#Three quotation marks can also print multiple lines
# Out:
# Hello, World!
#
# This is the first line.
# This is the second line.
# Three quotes can be used also
# to print multiple lines using a single print function
